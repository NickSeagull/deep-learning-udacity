# %% [markdown]
# Deep Learning
# =============
#
# Assignment 6
# ------------
#
# After training a skip-gram model in `5_word2vec.ipynb`, the goal of this notebook is to train a LSTM character model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import os
import numpy as np
import random
import string
import tensorflow as tf
import zipfile
from six.moves import range
from six.moves.urllib.request import urlretrieve

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
  f = zipfile.ZipFile(filename)
  for name in f.namelist():
    return tf.compat.as_str(f.read(name))
  f.close()
  
text = read_data(filename)
print('Data size %d' % len(text))
# Out:
# Data size 100000000

# %% [markdown]
# Create a small validation set.

# %%
valid_size = 1000
valid_text = text[:valid_size]
train_text = text[valid_size:]
train_size = len(train_text)
print(train_size, train_text[:64])
print(valid_size, valid_text[:64])
# Out:
# 99999000 ons anarchists advocate social relations based upon voluntary as
# 1000  anarchism originated as a term of abuse first used against earl

# %% [markdown]
# Utility functions to map characters to vocabulary IDs and back.

# %%
vocabulary_size = len(string.ascii_lowercase) + 1 # [a-z] + ' '
first_letter = ord(string.ascii_lowercase[0])

def char2id(char):
  if char in string.ascii_lowercase:
    return ord(char) - first_letter + 1
  elif char == ' ':
    return 0
  else:
    print('Unexpected character: %s' % char)
    return 0
  
def id2char(dictid):
  if dictid > 0:
    return chr(dictid + first_letter - 1)
  else:
    return ' '

print(char2id('a'), char2id('z'), char2id(' '), char2id('ï'))
print(id2char(1), id2char(26), id2char(0))
# Out:
# Unexpected character: ï
# 1 26 0 0
# a z

# %% [markdown]
# Function to generate a training batch for the LSTM model.

# %%
batch_size=64
num_unrollings=10

class BatchGenerator(object):
  def __init__(self, text, batch_size, num_unrollings):
    self._text = text
    self._text_size = len(text)
    self._batch_size = batch_size
    self._num_unrollings = num_unrollings
    segment = self._text_size // batch_size
    self._cursor = [ offset * segment for offset in range(batch_size)]
    self._last_batch = self._next_batch()
  
  def _next_batch(self):
    """Generate a single batch from the current cursor position in the data."""
    batch = np.zeros(shape=(self._batch_size, vocabulary_size), dtype=np.float)
    for b in range(self._batch_size):
      batch[b, char2id(self._text[self._cursor[b]])] = 1.0
      self._cursor[b] = (self._cursor[b] + 1) % self._text_size
    return batch
  
  def next(self):
    """Generate the next array of batches from the data. The array consists of
    the last batch of the previous array, followed by num_unrollings new ones.
    """
    batches = [self._last_batch]
    for step in range(self._num_unrollings):
      batches.append(self._next_batch())
    self._last_batch = batches[-1]
    return batches

def characters(probabilities):
  """Turn a 1-hot encoding or a probability distribution over the possible
  characters back into its (most likely) character representation."""
  return [id2char(c) for c in np.argmax(probabilities, 1)]

def batches2string(batches):
  """Convert a sequence of batches back into their (most likely) string
  representation."""
  s = [''] * batches[0].shape[0]
  for b in batches:
    s = [''.join(x) for x in zip(s, characters(b))]
  return s

train_batches = BatchGenerator(train_text, batch_size, num_unrollings)
valid_batches = BatchGenerator(valid_text, 1, 1)

print(batches2string(train_batches.next()))
print(batches2string(train_batches.next()))
print(batches2string(valid_batches.next()))
print(batches2string(valid_batches.next()))
# Out:
# ['ons anarchi', 'when milita', 'lleria arch', ' abbeys and', 'married urr', 'hel and ric', 'y and litur', 'ay opened f', 'tion from t', 'migration t', 'new york ot', 'he boeing s', 'e listed wi', 'eber has pr', 'o be made t', 'yer who rec', 'ore signifi', 'a fierce cr', ' two six ei', 'aristotle s', 'ity can be ', ' and intrac', 'tion of the', 'dy to pass ', 'f certain d', 'at it will ', 'e convince ', 'ent told hi', 'ampaign and', 'rver side s', 'ious texts ', 'o capitaliz', 'a duplicate', 'gh ann es d', 'ine january', 'ross zero t', 'cal theorie', 'ast instanc', ' dimensiona', 'most holy m', 't s support', 'u is still ', 'e oscillati', 'o eight sub', 'of italy la', 's the tower', 'klahoma pre', 'erprise lin', 'ws becomes ', 'et in a naz', 'the fabian ', 'etchy to re', ' sharman ne', 'ised empero', 'ting in pol', 'd neo latin', 'th risky ri', 'encyclopedi', 'fense the a', 'duating fro', 'treet grid ', 'ations more', 'appeal of d', 'si have mad']
# ['ists advoca', 'ary governm', 'hes nationa', 'd monasteri', 'raca prince', 'chard baer ', 'rgical lang', 'for passeng', 'the nationa', 'took place ', 'ther well k', 'seven six s', 'ith a gloss', 'robably bee', 'to recogniz', 'ceived the ', 'icant than ', 'ritic of th', 'ight in sig', 's uncaused ', ' lost as in', 'cellular ic', 'e size of t', ' him a stic', 'drugs confu', ' take to co', ' the priest', 'im to name ', 'd barred at', 'standard fo', ' such as es', 'ze on the g', 'e of the or', 'd hiver one', 'y eight mar', 'the lead ch', 'es classica', 'ce the non ', 'al analysis', 'mormons bel', 't or at lea', ' disagreed ', 'ing system ', 'btypes base', 'anguages th', 'r commissio', 'ess one nin', 'nux suse li', ' the first ', 'zi concentr', ' society ne', 'elatively s', 'etworks sha', 'or hirohito', 'litical ini', 'n most of t', 'iskerdoo ri', 'ic overview', 'air compone', 'om acnm acc', ' centerline', 'e than any ', 'devotional ', 'de such dev']
# [' a']
# ['an']

# %%
def logprob(predictions, labels):
  """Log-probability of the true labels in a predicted batch."""
  predictions[predictions < 1e-10] = 1e-10
  return np.sum(np.multiply(labels, -np.log(predictions))) / labels.shape[0]

def sample_distribution(distribution):
  """Sample one element from a distribution assumed to be an array of normalized
  probabilities.
  """
  r = random.uniform(0, 1)
  s = 0
  for i in range(len(distribution)):
    s += distribution[i]
    if s >= r:
      return i
  return len(distribution) - 1

def sample(prediction):
  """Turn a (column) prediction into 1-hot encoded samples."""
  p = np.zeros(shape=[1, vocabulary_size], dtype=np.float)
  p[0, sample_distribution(prediction[0])] = 1.0
  return p

def random_distribution():
  """Generate a random column of probabilities."""
  b = np.random.uniform(0.0, 1.0, size=[1, vocabulary_size])
  return b/np.sum(b, 1)[:,None]

# %% [markdown]
# Simple LSTM Model.

# %%
num_nodes = 64

graph = tf.Graph()
with graph.as_default():
  
  # Parameters:
  # Input gate: input, previous output, and bias.
  ix = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  im = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ib = tf.Variable(tf.zeros([1, num_nodes]))
  # Forget gate: input, previous output, and bias.
  fx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  fm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  fb = tf.Variable(tf.zeros([1, num_nodes]))
  # Memory cell: input, state and bias.                             
  cx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  cm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  cb = tf.Variable(tf.zeros([1, num_nodes]))
  # Output gate: input, previous output, and bias.
  ox = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  om = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ob = tf.Variable(tf.zeros([1, num_nodes]))
  # Variables saving state across unrollings.
  saved_output = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  saved_state = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  # Classifier weights and biases.
  w = tf.Variable(tf.truncated_normal([num_nodes, vocabulary_size], -0.1, 0.1))
  b = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Definition of the cell computation.
  def lstm_cell(i, o, state):
    """Create a LSTM cell. See e.g.: http://arxiv.org/pdf/1402.1128v1.pdf
    Note that in this formulation, we omit the various connections between the
    previous state and the gates."""
    input_gate = tf.sigmoid(tf.matmul(i, ix) + tf.matmul(o, im) + ib)
    forget_gate = tf.sigmoid(tf.matmul(i, fx) + tf.matmul(o, fm) + fb)
    update = tf.matmul(i, cx) + tf.matmul(o, cm) + cb
    state = forget_gate * state + input_gate * tf.tanh(update)
    output_gate = tf.sigmoid(tf.matmul(i, ox) + tf.matmul(o, om) + ob)
    return output_gate * tf.tanh(state), state

  # Input data.
  train_data = list()
  for _ in range(num_unrollings + 1):
    train_data.append(
      tf.placeholder(tf.float32, shape=[batch_size,vocabulary_size]))
  train_inputs = train_data[:num_unrollings]
  train_labels = train_data[1:]  # labels are inputs shifted by one time step.

  # Unrolled LSTM loop.
  outputs = list()
  output = saved_output
  state = saved_state
  for i in train_inputs:
    output, state = lstm_cell(i, output, state)
    outputs.append(output)

  # State saving across unrollings.
  with tf.control_dependencies([saved_output.assign(output),
                                saved_state.assign(state)]):
    # Classifier.
    logits = tf.nn.xw_plus_b(tf.concat(0, outputs), w, b)
    loss = tf.reduce_mean(
      tf.nn.softmax_cross_entropy_with_logits(
        logits, tf.concat(0, train_labels)))

  # Optimizer.
  global_step = tf.Variable(0)
  learning_rate = tf.train.exponential_decay(
    10.0, global_step, 5000, 0.1, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate)
  gradients, v = zip(*optimizer.compute_gradients(loss))
  gradients, _ = tf.clip_by_global_norm(gradients, 1.25)
  optimizer = optimizer.apply_gradients(
    zip(gradients, v), global_step=global_step)

  # Predictions.
  train_prediction = tf.nn.softmax(logits)
  
  # Sampling and validation eval: batch 1, no unrolling.
  sample_input = tf.placeholder(tf.float32, shape=[1, vocabulary_size])
  saved_sample_output = tf.Variable(tf.zeros([1, num_nodes]))
  saved_sample_state = tf.Variable(tf.zeros([1, num_nodes]))
  reset_sample_state = tf.group(
    saved_sample_output.assign(tf.zeros([1, num_nodes])),
    saved_sample_state.assign(tf.zeros([1, num_nodes])))
  sample_output, sample_state = lstm_cell(
    sample_input, saved_sample_output, saved_sample_state)
  with tf.control_dependencies([saved_sample_output.assign(sample_output),
                                saved_sample_state.assign(sample_state)]):
    sample_prediction = tf.nn.softmax(tf.nn.xw_plus_b(sample_output, w, b))

# %%
num_steps = 7001
summary_frequency = 100

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  mean_loss = 0
  for step in range(num_steps):
    batches = train_batches.next()
    feed_dict = dict()
    for i in range(num_unrollings + 1):
      feed_dict[train_data[i]] = batches[i]
    _, l, predictions, lr = session.run(
      [optimizer, loss, train_prediction, learning_rate], feed_dict=feed_dict)
    mean_loss += l
    if step % summary_frequency == 0:
      if step > 0:
        mean_loss = mean_loss / summary_frequency
      # The mean loss is an estimate of the loss over the last few batches.
      print(
        'Average loss at step %d: %f learning rate: %f' % (step, mean_loss, lr))
      mean_loss = 0
      labels = np.concatenate(list(batches)[1:])
      print('Minibatch perplexity: %.2f' % float(
        np.exp(logprob(predictions, labels))))
      if step % (summary_frequency * 10) == 0:
        # Generate some samples.
        print('=' * 80)
        for _ in range(5):
          feed = sample(random_distribution())
          sentence = characters(feed)[0]
          reset_sample_state.run()
          for _ in range(79):
            prediction = sample_prediction.eval({sample_input: feed})
            feed = sample(prediction)
            sentence += characters(feed)[0]
          print(sentence)
        print('=' * 80)
      # Measure validation set perplexity.
      reset_sample_state.run()
      valid_logprob = 0
      for _ in range(valid_size):
        b = valid_batches.next()
        predictions = sample_prediction.eval({sample_input: b[0]})
        valid_logprob = valid_logprob + logprob(predictions, b[1])
      print('Validation set perplexity: %.2f' % float(np.exp(
        valid_logprob / valid_size)))
# Out:
# Initialized
# Average loss at step 0: 3.299743 learning rate: 10.000000
# Minibatch perplexity: 27.11
# ================================================================================
# veqwe ecr idvxbje wjo nsfd alpsgy ehtapomxtyhidjt pryypu  pw ngtaf sluxl  ed rab
# naesh encc m ymfrytmlwxeb mrgnszi wz  i n pstai ubecnbndbzoaelwaicdipem vil deeb
# enwdzmjx  dk dnrfx gax  bat mptnv  u glcxkme  aljonowzcducoxbn fxjxkqjp i a bdas
# n bmonqb xcei vsh i  sikuojbv qba  qff hdqtemoestyhywtlhddytedqm lnbdkunvs   apq
#  mkhpp j vittngheadyeljvx aes bibuvet ajfiw ipso mrnhtaima ibi kozd  opeoaoppdte
# ================================================================================
# Validation set perplexity: 20.07
# Average loss at step 100: 2.602129 learning rate: 10.000000
# Minibatch perplexity: 11.08
# Validation set perplexity: 10.48
# Average loss at step 200: 2.250860 learning rate: 10.000000
# Minibatch perplexity: 8.90
# Validation set perplexity: 8.82
# Average loss at step 300: 2.100961 learning rate: 10.000000
# Minibatch perplexity: 7.37
# Validation set perplexity: 8.04
# Average loss at step 400: 1.998165 learning rate: 10.000000
# Minibatch perplexity: 7.44
# Validation set perplexity: 7.79
# Average loss at step 500: 1.934182 learning rate: 10.000000
# Minibatch perplexity: 6.41
# Validation set perplexity: 7.19
# Average loss at step 600: 1.907532 learning rate: 10.000000
# Minibatch perplexity: 6.22
# Validation set perplexity: 6.93
# Average loss at step 700: 1.860871 learning rate: 10.000000
# Minibatch perplexity: 6.49
# Validation set perplexity: 6.65
# Average loss at step 800: 1.818932 learning rate: 10.000000
# Minibatch perplexity: 6.00
# Validation set perplexity: 6.41
# Average loss at step 900: 1.831621 learning rate: 10.000000
# Minibatch perplexity: 6.97
# Validation set perplexity: 6.33
# Average loss at step 1000: 1.825899 learning rate: 10.000000
# Minibatch perplexity: 5.57
# ================================================================================
# wes hoge ty deowh the the freaders imms cele the reace spaic one nine seven seve
# h dewere of so soper thelevinent wath the shury fear in decongencianaly of the t
# wate evers he intercu dechine ervike treate fine one hine alver ciming reform a
# php woryd over intorial he wend hissoda repenps of two a frol the by or aurce fr
# y sking theary a sparcan efend hiteshia seaketale see hik his the earche is hedr
# ================================================================================
# Validation set perplexity: 6.09
# Average loss at step 1100: 1.775492 learning rate: 10.000000
# Minibatch perplexity: 5.64
# Validation set perplexity: 5.95
# Average loss at step 1200: 1.753970 learning rate: 10.000000
# Minibatch perplexity: 5.06
# Validation set perplexity: 5.72
# Average loss at step 1300: 1.733280 learning rate: 10.000000
# Minibatch perplexity: 5.68
# Validation set perplexity: 5.75
# Average loss at step 1400: 1.749282 learning rate: 10.000000
# Minibatch perplexity: 5.85
# Validation set perplexity: 5.61
# Average loss at step 1500: 1.739804 learning rate: 10.000000
# Minibatch perplexity: 4.86
# Validation set perplexity: 5.53
# Average loss at step 1600: 1.747943 learning rate: 10.000000
# Minibatch perplexity: 5.53
# Validation set perplexity: 5.50
# Average loss at step 1700: 1.712197 learning rate: 10.000000
# Minibatch perplexity: 5.74
# Validation set perplexity: 5.48
# Average loss at step 1800: 1.673827 learning rate: 10.000000
# Minibatch perplexity: 5.27
# Validation set perplexity: 5.33
# Average loss at step 1900: 1.648668 learning rate: 10.000000
# Minibatch perplexity: 5.13
# Validation set perplexity: 5.16
# Average loss at step 2000: 1.693083 learning rate: 10.000000
# Minibatch perplexity: 5.62
# ================================================================================
# y fomever apounce catter over notlot milsion to diber a most indieith he demette
# e and use a set mattart s not banoliinsta s w this x targion erican bat couse sm
# chule found englizh amprobon binging r sposition in lite sope mame nectoblabland
# uth is resincl goye was sten that conulis hind vackern  bewa to mainsion worm fr
# quans edduty importain asmatically seepor petal his not f the lasiles afrersist
# ================================================================================
# Validation set perplexity: 5.19
# Average loss at step 2100: 1.680109 learning rate: 10.000000
# Minibatch perplexity: 5.22
# Validation set perplexity: 4.99
# Average loss at step 2200: 1.679033 learning rate: 10.000000
# Minibatch perplexity: 6.50
# Validation set perplexity: 5.02
# Average loss at step 2300: 1.638773 learning rate: 10.000000
# Minibatch perplexity: 5.09
# Validation set perplexity: 4.89
# Average loss at step 2400: 1.659791 learning rate: 10.000000
# Minibatch perplexity: 5.18
# Validation set perplexity: 4.90
# Average loss at step 2500: 1.681026 learning rate: 10.000000
# Minibatch perplexity: 5.50
# Validation set perplexity: 4.65
# Average loss at step 2600: 1.649016 learning rate: 10.000000
# Minibatch perplexity: 5.75
# Validation set perplexity: 4.64
# Average loss at step 2700: 1.652504 learning rate: 10.000000
# Minibatch perplexity: 4.67
# Validation set perplexity: 4.78
# Average loss at step 2800: 1.648687 learning rate: 10.000000
# Minibatch perplexity: 5.63
# Validation set perplexity: 4.62
# Average loss at step 2900: 1.648656 learning rate: 10.000000
# Minibatch perplexity: 5.60
# Validation set perplexity: 4.76
# Average loss at step 3000: 1.647721 learning rate: 10.000000
# Minibatch perplexity: 5.02
# ================================================================================
# e art and forments cult one five five digerial anfor stared their on closped in
# ped mutra ma budy don freed comp a upes and is and and reoks on syd composed to
# ja foom med be recome tromments of states kinglony five by assidise of by rietsi
# hers include with infouttles with thougolog yerval namet the several their pasid
# uni and doblists repartidis to the vic formersion of formals uloghity rezidal s
# ================================================================================
# Validation set perplexity: 4.68
# Average loss at step 3100: 1.626054 learning rate: 10.000000
# Minibatch perplexity: 5.70
# Validation set perplexity: 4.65
# Average loss at step 3200: 1.644692 learning rate: 10.000000
# Minibatch perplexity: 5.42
# Validation set perplexity: 4.60
# Average loss at step 3300: 1.636992 learning rate: 10.000000
# Minibatch perplexity: 5.24
# Validation set perplexity: 4.49
# Average loss at step 3400: 1.663971 learning rate: 10.000000
# Minibatch perplexity: 5.56
# Validation set perplexity: 4.47
# Average loss at step 3500: 1.653386 learning rate: 10.000000
# Minibatch perplexity: 5.56
# Validation set perplexity: 4.56
# Average loss at step 3600: 1.668529 learning rate: 10.000000
# Minibatch perplexity: 4.56
# Validation set perplexity: 4.47
# Average loss at step 3700: 1.642935 learning rate: 10.000000
# Minibatch perplexity: 5.15
# Validation set perplexity: 4.56
# Average loss at step 3800: 1.645331 learning rate: 10.000000
# Minibatch perplexity: 5.64
# Validation set perplexity: 4.59
# Average loss at step 3900: 1.632283 learning rate: 10.000000
# Minibatch perplexity: 5.33
# Validation set perplexity: 4.53
# Average loss at step 4000: 1.652080 learning rate: 10.000000
# Minibatch perplexity: 4.70
# ================================================================================
# balmd or eeaer of belokoy he shocishize which after europe the includem to be bl
# kay on seeferti the performs herropobly litteba so doma or consenty decerented a
# pant to tepe those witha has and ftil nine one nine eight that eartics menth fro
# agow beipir externial the one nine yive obe creatures prosecticized celfseare me
# quens centres in union master ur subses in dubered the early indinarors more bid
# ================================================================================
# Validation set perplexity: 4.52
# Average loss at step 4100: 1.632358 learning rate: 10.000000
# Minibatch perplexity: 5.25
# Validation set perplexity: 4.58
# Average loss at step 4200: 1.636510 learning rate: 10.000000
# Minibatch perplexity: 5.37
# Validation set perplexity: 4.43
# Average loss at step 4300: 1.611053 learning rate: 10.000000
# Minibatch perplexity: 5.06
# Validation set perplexity: 4.40
# Average loss at step 4400: 1.605041 learning rate: 10.000000
# Minibatch perplexity: 4.82
# Validation set perplexity: 4.35
# Average loss at step 4500: 1.617976 learning rate: 10.000000
# Minibatch perplexity: 5.32
# Validation set perplexity: 4.56
# Average loss at step 4600: 1.614539 learning rate: 10.000000
# Minibatch perplexity: 4.95
# Validation set perplexity: 4.50
# Average loss at step 4700: 1.629829 learning rate: 10.000000
# Minibatch perplexity: 5.24
# Validation set perplexity: 4.52
# Average loss at step 4800: 1.627043 learning rate: 10.000000
# Minibatch perplexity: 4.47
# Validation set perplexity: 4.46
# Average loss at step 4900: 1.633769 learning rate: 10.000000
# Minibatch perplexity: 5.11
# Validation set perplexity: 4.54
# Average loss at step 5000: 1.603587 learning rate: 1.000000
# Minibatch perplexity: 4.44
# ================================================================================
# word in the methity in who mar and an with that and interrcentestries his prepub
# ge aburses while heaply has thi bastee advantino or peopro democrated pirch fort
# d in beachnishing one is the prepiery seased in d e yousokoph yorbic in sinder s
# siation histore skpenchtts b exists alfort an and between for the gould north le
# fice the severally ottic good the life consus minuly one two zero zero seven sin
# ================================================================================
# Validation set perplexity: 4.68
# Average loss at step 5100: 1.604213 learning rate: 1.000000
# Minibatch perplexity: 4.94
# Validation set perplexity: 4.45
# Average loss at step 5200: 1.585947 learning rate: 1.000000
# Minibatch perplexity: 4.57
# Validation set perplexity: 4.37
# Average loss at step 5300: 1.575965 learning rate: 1.000000
# Minibatch perplexity: 4.63
# Validation set perplexity: 4.36
# Average loss at step 5400: 1.578018 learning rate: 1.000000
# Minibatch perplexity: 5.07
# Validation set perplexity: 4.35
# Average loss at step 5500: 1.566461 learning rate: 1.000000
# Minibatch perplexity: 4.81
# Validation set perplexity: 4.31
# Average loss at step 5600: 1.579006 learning rate: 1.000000
# Minibatch perplexity: 4.86
# Validation set perplexity: 4.28
# Average loss at step 5700: 1.566875 learning rate: 1.000000
# Minibatch perplexity: 4.63
# Validation set perplexity: 4.28
# Average loss at step 5800: 1.573140 learning rate: 1.000000
# Minibatch perplexity: 4.83
# Validation set perplexity: 4.26
# Average loss at step 5900: 1.569343 learning rate: 1.000000
# Minibatch perplexity: 5.16
# Validation set perplexity: 4.24
# Average loss at step 6000: 1.545616 learning rate: 1.000000
# Minibatch perplexity: 5.10
# ================================================================================
# men lore edstunded by a reed the council two and cueth then throudd maxofiate to
# ine zero doagys lange three spaueme one s brow hormed loak refine kng tzourt say
# waly trygn theee system play of perment revinmentian chihoquextibully life serie
#  dryand someta enterts five undering that jenotisu the famker ruptinees law rape
# e bayor quanage tarlic gawnes is wrottining lared oclatiom law zero brote that a
# ================================================================================
# Validation set perplexity: 4.23
# Average loss at step 6100: 1.560832 learning rate: 1.000000
# Minibatch perplexity: 4.97
# Validation set perplexity: 4.21
# Average loss at step 6200: 1.527695 learning rate: 1.000000
# Minibatch perplexity: 4.70
# Validation set perplexity: 4.23
# Average loss at step 6300: 1.542323 learning rate: 1.000000
# Minibatch perplexity: 5.01
# Validation set perplexity: 4.23
# Average loss at step 6400: 1.535138 learning rate: 1.000000
# Minibatch perplexity: 4.34
# Validation set perplexity: 4.23
# Average loss at step 6500: 1.552822 learning rate: 1.000000
# Minibatch perplexity: 4.68
# Validation set perplexity: 4.24
# Average loss at step 6600: 1.595744 learning rate: 1.000000
# Minibatch perplexity: 4.87
# Validation set perplexity: 4.22
# Average loss at step 6700: 1.581036 learning rate: 1.000000
# Minibatch perplexity: 5.22
# Validation set perplexity: 4.24
# Average loss at step 6800: 1.603232 learning rate: 1.000000
# Minibatch perplexity: 4.69
# Validation set perplexity: 4.23
# Average loss at step 6900: 1.584081 learning rate: 1.000000
# Minibatch perplexity: 4.62
# Validation set perplexity: 4.25
# Average loss at step 7000: 1.570487 learning rate: 1.000000
# Minibatch perplexity: 4.98
# ================================================================================
# ward histor on impines on one nine zero eight dezines two five servines buse by
# ore interest frankia priet havia mose ineving to persule starter bows areas in h
# p instilutione is however ett for arks successived writer to would and the seven
# dical cuburative s l erchnanompt gidsand eactine requirete may billo universon n
# quency is gain exnotoprease ronners numbing poter providued to is british occonc
# ================================================================================
# Validation set perplexity: 4.21

# %% [markdown]
# ---
# Problem 1
# ---------
#
# You might have noticed that the definition of the LSTM cell involves 4 matrix multiplications with the input, and 4 matrix multiplications with the output. Simplify the expression by using a single matrix multiply for each, and variables that are 4 times larger.
#
# ---

# %%
num_nodes = 64

graph = tf.Graph()
with graph.as_default():
  
  # Parameters:
  ## Input gate: input, previous output, and bias.
  #ix = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  #im = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  #ib = tf.Variable(tf.zeros([1, num_nodes]))
  ## Forget gate: input, previous output, and bias.
  #fx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  #fm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  #fb = tf.Variable(tf.zeros([1, num_nodes]))
  ## Memory cell: input, state and bias.                             
  #cx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  #cm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  #cb = tf.Variable(tf.zeros([1, num_nodes]))
  ## Output gate: input, previous output, and bias.
  #ox = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  #om = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  #ob = tf.Variable(tf.zeros([1, num_nodes]))
    
  ifcox = tf.Variable(tf.truncated_normal([vocabulary_size, 4*num_nodes], -0.1, 0.1))
  ifcom = tf.Variable(tf.truncated_normal([num_nodes, 4*num_nodes], -0.1, 0.1))
  ifcob = tf.Variable(tf.zeros([1, 4*num_nodes]))
  # Variables saving state across unrollings.
  saved_output = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  saved_state = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  # Classifier weights and biases.
  w = tf.Variable(tf.truncated_normal([num_nodes, vocabulary_size], -0.1, 0.1))
  b = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Definition of the cell computation.
  def lstm_cell(i, o, state):
    """Create a LSTM cell. See e.g.: http://arxiv.org/pdf/1402.1128v1.pdf
    Note that in this formulation, we omit the various connections between the
    previous state and the gates."""
    #input_gate = tf.sigmoid(tf.matmul(i, ix) + tf.matmul(o, im) + ib)
    #forget_gate = tf.sigmoid(tf.matmul(i, fx) + tf.matmul(o, fm) + fb)
    #update = tf.matmul(i, cx) + tf.matmul(o, cm) + cb
    #state = forget_gate * state + input_gate * tf.tanh(update)
    #output_gate = tf.sigmoid(tf.matmul(i, ox) + tf.matmul(o, om) + ob)
    
    
    all_gates_state = tf.matmul(i, ifcox) + tf.matmul(o, ifcom) + ifcob
    input_gate = tf.sigmoid(all_gates_state[:, 0:num_nodes])
    forget_gate = tf.sigmoid(all_gates_state[:, num_nodes: 2*num_nodes])
    update = all_gates_state[:, 2*num_nodes: 3*num_nodes]
    state = forget_gate * state + input_gate * tf.tanh(update)
    output_gate = tf.sigmoid(all_gates_state[:, 3*num_nodes:])
    return output_gate * tf.tanh(state), state

  # Input data.
  train_data = list()
  for _ in range(num_unrollings + 1):
    train_data.append(
      tf.placeholder(tf.float32, shape=[batch_size,vocabulary_size]))
  train_inputs = train_data[:num_unrollings]
  train_labels = train_data[1:]  # labels are inputs shifted by one time step.

  # Unrolled LSTM loop.
  outputs = list()
  output = saved_output
  state = saved_state
  for i in train_inputs:
    output, state = lstm_cell(i, output, state)
    outputs.append(output)

  # State saving across unrollings.
  with tf.control_dependencies([saved_output.assign(output),
                                saved_state.assign(state)]):
    # Classifier.
    logits = tf.nn.xw_plus_b(tf.concat(0, outputs), w, b)
    loss = tf.reduce_mean(
      tf.nn.softmax_cross_entropy_with_logits(
        logits, tf.concat(0, train_labels)))

  # Optimizer.
  global_step = tf.Variable(0)
  learning_rate = tf.train.exponential_decay(
    10.0, global_step, 5000, 0.1, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate)
  gradients, v = zip(*optimizer.compute_gradients(loss))
  gradients, _ = tf.clip_by_global_norm(gradients, 1.25)
  optimizer = optimizer.apply_gradients(
    zip(gradients, v), global_step=global_step)

  # Predictions.
  train_prediction = tf.nn.softmax(logits)
  
  # Sampling and validation eval: batch 1, no unrolling.
  sample_input = tf.placeholder(tf.float32, shape=[1, vocabulary_size])
  saved_sample_output = tf.Variable(tf.zeros([1, num_nodes]))
  saved_sample_state = tf.Variable(tf.zeros([1, num_nodes]))
  reset_sample_state = tf.group(
    saved_sample_output.assign(tf.zeros([1, num_nodes])),
    saved_sample_state.assign(tf.zeros([1, num_nodes])))
  sample_output, sample_state = lstm_cell(
    sample_input, saved_sample_output, saved_sample_state)
  with tf.control_dependencies([saved_sample_output.assign(sample_output),
                                saved_sample_state.assign(sample_state)]):
    sample_prediction = tf.nn.softmax(tf.nn.xw_plus_b(sample_output, w, b))

# %%
num_steps = 7001
summary_frequency = 100

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  mean_loss = 0
  for step in range(num_steps):
    batches = train_batches.next()
    feed_dict = dict()
    for i in range(num_unrollings + 1):
      feed_dict[train_data[i]] = batches[i]
    _, l, predictions, lr = session.run(
      [optimizer, loss, train_prediction, learning_rate], feed_dict=feed_dict)
    mean_loss += l
    if step % summary_frequency == 0:
      if step > 0:
        mean_loss = mean_loss / summary_frequency
      # The mean loss is an estimate of the loss over the last few batches.
      print(
        'Average loss at step %d: %f learning rate: %f' % (step, mean_loss, lr))
      mean_loss = 0
      labels = np.concatenate(list(batches)[1:])
      print('Minibatch perplexity: %.2f' % float(
        np.exp(logprob(predictions, labels))))
      if step % (summary_frequency * 10) == 0:
        # Generate some samples.
        print('=' * 80)
        for _ in range(5):
          feed = sample(random_distribution())
          sentence = characters(feed)[0]
          reset_sample_state.run()
          for _ in range(79):
            prediction = sample_prediction.eval({sample_input: feed})
            feed = sample(prediction)
            sentence += characters(feed)[0]
          print(sentence)
        print('=' * 80)
      # Measure validation set perplexity.
      reset_sample_state.run()
      valid_logprob = 0
      for _ in range(valid_size):
        b = valid_batches.next()
        predictions = sample_prediction.eval({sample_input: b[0]})
        valid_logprob = valid_logprob + logprob(predictions, b[1])
      print('Validation set perplexity: %.2f' % float(np.exp(
        valid_logprob / valid_size)))
# Out:
# Initialized
# Average loss at step 0: 3.293377 learning rate: 10.000000
# Minibatch perplexity: 26.93
# ================================================================================
# po ym lzutuihi bxex ucvvqt  hl sdnydtf mc hbfou eekettsonnsmoswkdeoam   vu oqkht
# dlc vu wjiheygd s bnyf rbtnh atkdltsuajj wftahgz rlid nl sdlranfmw vl d yo otr o
# dss aieomptuuemacn edizac wnr osrlcvejjiguenhw en toeaxsakr btapnsjp syi rhmsxg
# dkndqi cg zg lvisfexj nvmsegjqrthelok trszaz sgo u koo wrnmss  nmie th wvgmn nei
# el p y  aez lalfmbreyqjycn mmapvaeickrrvdngbhtfieagzrrmkslh  tz rrbep rhf toty b
# ================================================================================
# Validation set perplexity: 19.90
# Average loss at step 100: 2.593230 learning rate: 10.000000
# Minibatch perplexity: 11.21
# Validation set perplexity: 12.16
# Average loss at step 200: 2.248885 learning rate: 10.000000
# Minibatch perplexity: 8.31
# Validation set perplexity: 8.71
# Average loss at step 300: 2.080215 learning rate: 10.000000
# Minibatch perplexity: 6.29
# Validation set perplexity: 7.97
# Average loss at step 400: 2.028352 learning rate: 10.000000
# Minibatch perplexity: 7.88
# Validation set perplexity: 7.81
# Average loss at step 500: 1.973563 learning rate: 10.000000
# Minibatch perplexity: 6.38
# Validation set perplexity: 6.95
# Average loss at step 600: 1.890506 learning rate: 10.000000
# Minibatch perplexity: 6.36
# Validation set perplexity: 6.93
# Average loss at step 700: 1.866158 learning rate: 10.000000
# Minibatch perplexity: 6.90
# Validation set perplexity: 6.52
# Average loss at step 800: 1.860760 learning rate: 10.000000
# Minibatch perplexity: 6.91
# Validation set perplexity: 6.46
# Average loss at step 900: 1.838184 learning rate: 10.000000
# Minibatch perplexity: 6.03
# Validation set perplexity: 6.27
# Average loss at step 1000: 1.839303 learning rate: 10.000000
# Minibatch perplexity: 6.45
# ================================================================================
# an west s anmif iste ial duspaciut dison is in consisial d e gined woir usor the
# quidic furtrant its a nover one five four of the macreter with dtsd capeosing mo
# fer c lid s hemzeria anchara ople s me tavin used tern fwormaters sermertim tamp
# w two exven as pruc anthough twan strapes is alpion of the continium reneticy on
# net but incessarial throue in phy oclinet gus duthes isiqies in the brox was the
# ================================================================================
# Validation set perplexity: 6.02
# Average loss at step 1100: 1.796841 learning rate: 10.000000
# Minibatch perplexity: 5.30
# Validation set perplexity: 6.08
# Average loss at step 1200: 1.765174 learning rate: 10.000000
# Minibatch perplexity: 6.40
# Validation set perplexity: 5.90
# Average loss at step 1300: 1.758232 learning rate: 10.000000
# Minibatch perplexity: 5.84
# Validation set perplexity: 5.86
# Average loss at step 1400: 1.762149 learning rate: 10.000000
# Minibatch perplexity: 6.34
# Validation set perplexity: 5.75
# Average loss at step 1500: 1.748639 learning rate: 10.000000
# Minibatch perplexity: 5.73
# Validation set perplexity: 5.52
# Average loss at step 1600: 1.732056 learning rate: 10.000000
# Minibatch perplexity: 5.50
# Validation set perplexity: 5.68
# Average loss at step 1700: 1.714636 learning rate: 10.000000
# Minibatch perplexity: 5.16
# Validation set perplexity: 5.42
# Average loss at step 1800: 1.690931 learning rate: 10.000000
# Minibatch perplexity: 5.08
# Validation set perplexity: 5.26
# Average loss at step 1900: 1.694639 learning rate: 10.000000
# Minibatch perplexity: 5.03
# Validation set perplexity: 5.41
# Average loss at step 2000: 1.675979 learning rate: 10.000000
# Minibatch perplexity: 4.90
# ================================================================================
# dhs from antwsenter vilt usubliss tester pession of the p by spear timate certy
# zend then most to the can dembeding nestuage link file suepicitial mos ng offere
# gis lightates tubly was airssifuctract in an hadeard present whell exvants velog
# obhs west br boli fire and wide loss secies for than coustinution for arsumise b
# al glough rueding callast that on genent frant to hecks prodected ius tamence pa
# ================================================================================
# Validation set perplexity: 5.26
# Average loss at step 2100: 1.684361 learning rate: 10.000000
# Minibatch perplexity: 4.96
# Validation set perplexity: 5.31
# Average loss at step 2200: 1.704361 learning rate: 10.000000
# Minibatch perplexity: 4.94
# Validation set perplexity: 5.13
# Average loss at step 2300: 1.702645 learning rate: 10.000000
# Minibatch perplexity: 6.32
# Validation set perplexity: 5.14
# Average loss at step 2400: 1.681998 learning rate: 10.000000
# Minibatch perplexity: 5.77
# Validation set perplexity: 5.27
# Average loss at step 2500: 1.685485 learning rate: 10.000000
# Minibatch perplexity: 5.88
# Validation set perplexity: 5.16
# Average loss at step 2600: 1.666275 learning rate: 10.000000
# Minibatch perplexity: 5.40
# Validation set perplexity: 5.01
# Average loss at step 2700: 1.681133 learning rate: 10.000000
# Minibatch perplexity: 5.34
# Validation set perplexity: 5.14
# Average loss at step 2800: 1.680231 learning rate: 10.000000
# Minibatch perplexity: 5.29
# Validation set perplexity: 5.24
# Average loss at step 2900: 1.671997 learning rate: 10.000000
# Minibatch perplexity: 6.24
# Validation set perplexity: 5.14
# Average loss at step 3000: 1.676860 learning rate: 10.000000
# Minibatch perplexity: 4.83
# ================================================================================
# y businest frogr of beofficaplitize pranutionon farrard don other pueling to reg
# n zero akeria k two one eers the s enuaking in two made time earth use eleasiol
# s the majo comma replocial to tws tch usion metotac field mevoutives of the russ
# line crestrettifur of deserpted is numinaning eflited alse the exchurt of itm ze
# tifing that amino is the frenchija seaced preadio on a alvembers piesable tasm w
# ================================================================================
# Validation set perplexity: 5.07
# Average loss at step 3100: 1.650584 learning rate: 10.000000
# Minibatch perplexity: 5.25
# Validation set perplexity: 5.03
# Average loss at step 3200: 1.633713 learning rate: 10.000000
# Minibatch perplexity: 5.47
# Validation set perplexity: 4.96
# Average loss at step 3300: 1.641699 learning rate: 10.000000
# Minibatch perplexity: 5.24
# Validation set perplexity: 4.87
# Average loss at step 3400: 1.629631 learning rate: 10.000000
# Minibatch perplexity: 5.26
# Validation set perplexity: 4.92
# Average loss at step 3500: 1.672846 learning rate: 10.000000
# Minibatch perplexity: 6.07
# Validation set perplexity: 4.91
# Average loss at step 3600: 1.649479 learning rate: 10.000000
# Minibatch perplexity: 5.26
# Validation set perplexity: 4.89
# Average loss at step 3700: 1.647433 learning rate: 10.000000
# Minibatch perplexity: 5.19
# Validation set perplexity: 4.90
# Average loss at step 3800: 1.652621 learning rate: 10.000000
# Minibatch perplexity: 6.17
# Validation set perplexity: 4.87
# Average loss at step 3900: 1.644662 learning rate: 10.000000
# Minibatch perplexity: 4.19
# Validation set perplexity: 4.85
# Average loss at step 4000: 1.636761 learning rate: 10.000000
# Minibatch perplexity: 5.32
# ================================================================================
# wern range of one nine tenenssartted sectry the indarams organis threatwouther a
#  c holdymea from hay off they mulantal mostfyii and anius deltgnkan fast irea la
# y mones the mirronal miljemant butchaden the officially was the umlater for anor
# ting the laser natues bexiname states britishus those for form curreether amomve
# kson the lipermation cidons to the willian calse as make and hars khen not sort
# ================================================================================
# Validation set perplexity: 4.71
# Average loss at step 4100: 1.619622 learning rate: 10.000000
# Minibatch perplexity: 4.69
# Validation set perplexity: 4.63
# Average loss at step 4200: 1.615867 learning rate: 10.000000
# Minibatch perplexity: 5.01
# Validation set perplexity: 4.65
# Average loss at step 4300: 1.620537 learning rate: 10.000000
# Minibatch perplexity: 5.56
# Validation set perplexity: 4.84
# Average loss at step 4400: 1.609189 learning rate: 10.000000
# Minibatch perplexity: 5.47
# Validation set perplexity: 4.68
# Average loss at step 4500: 1.636669 learning rate: 10.000000
# Minibatch perplexity: 5.02
# Validation set perplexity: 4.77
# Average loss at step 4600: 1.618736 learning rate: 10.000000
# Minibatch perplexity: 5.32
# Validation set perplexity: 4.71
# Average loss at step 4700: 1.615074 learning rate: 10.000000
# Minibatch perplexity: 4.87
# Validation set perplexity: 4.74
# Average loss at step 4800: 1.608948 learning rate: 10.000000
# Minibatch perplexity: 4.72
# Validation set perplexity: 4.74
# Average loss at step 4900: 1.617202 learning rate: 10.000000
# Minibatch perplexity: 5.19
# Validation set perplexity: 4.71
# Average loss at step 5000: 1.612680 learning rate: 1.000000
# Minibatch perplexity: 4.85
# ================================================================================
# x parvision of that by constrainwatined perstrungaon conlip smallend the world i
# ckish remating five mistic rukers to were moned the dirgua have that special con
# dated is ited gold vier wince the wan a shew dia of europe architecturing are be
# ent of the followard novy that the componed that be yoush one three seven tox ca
# ful labriin mills which theory inv besumemblefic that sharks world botk came coi
# ================================================================================
# Validation set perplexity: 4.69
# Average loss at step 5100: 1.592694 learning rate: 1.000000
# Minibatch perplexity: 5.17
# Validation set perplexity: 4.62
# Average loss at step 5200: 1.587429 learning rate: 1.000000
# Minibatch perplexity: 5.17
# Validation set perplexity: 4.60
# Average loss at step 5300: 1.594895 learning rate: 1.000000
# Minibatch perplexity: 5.18
# Validation set perplexity: 4.60
# Average loss at step 5400: 1.590079 learning rate: 1.000000
# Minibatch perplexity: 4.64
# Validation set perplexity: 4.55
# Average loss at step 5500: 1.581882 learning rate: 1.000000
# Minibatch perplexity: 5.38
# Validation set perplexity: 4.53
# Average loss at step 5600: 1.564071 learning rate: 1.000000
# Minibatch perplexity: 4.39
# Validation set perplexity: 4.48
# Average loss at step 5700: 1.576479 learning rate: 1.000000
# Minibatch perplexity: 4.72
# Validation set perplexity: 4.45
# Average loss at step 5800: 1.601382 learning rate: 1.000000
# Minibatch perplexity: 4.66
# Validation set perplexity: 4.48
# Average loss at step 5900: 1.581591 learning rate: 1.000000
# Minibatch perplexity: 5.29
# Validation set perplexity: 4.49
# Average loss at step 6000: 1.581957 learning rate: 1.000000
# Minibatch perplexity: 4.68
# ================================================================================
# ons the fina remains invext chilcsimal uised elemiting a cove face wem by the ea
#  the openst by progrims braphic general one zero s while sparge daing than two s
# ger alyant starting bodhaf was music is simpless of french one seven one through
# s impositions laxisher phocroronic meador on this otherong are study responsic t
# query couds formed and the since one five six nimtonent by novers s ves ottessio
# ================================================================================
# Validation set perplexity: 4.46
# Average loss at step 6100: 1.571145 learning rate: 1.000000
# Minibatch perplexity: 4.33
# Validation set perplexity: 4.49
# Average loss at step 6200: 1.584520 learning rate: 1.000000
# Minibatch perplexity: 4.70
# Validation set perplexity: 4.51
# Average loss at step 6300: 1.584016 learning rate: 1.000000
# Minibatch perplexity: 5.23
# Validation set perplexity: 4.53
# Average loss at step 6400: 1.568721 learning rate: 1.000000
# Minibatch perplexity: 4.18
# Validation set perplexity: 4.53
# Average loss at step 6500: 1.556218 learning rate: 1.000000
# Minibatch perplexity: 5.40
# Validation set perplexity: 4.55
# Average loss at step 6600: 1.597963 learning rate: 1.000000
# Minibatch perplexity: 5.58
# Validation set perplexity: 4.51
# Average loss at step 6700: 1.569481 learning rate: 1.000000
# Minibatch perplexity: 5.42
# Validation set perplexity: 4.53
# Average loss at step 6800: 1.574011 learning rate: 1.000000
# Minibatch perplexity: 4.82
# Validation set perplexity: 4.57
# Average loss at step 6900: 1.568783 learning rate: 1.000000
# Minibatch perplexity: 4.86
# Validation set perplexity: 4.54
# Average loss at step 7000: 1.585995 learning rate: 1.000000
# Minibatch perplexity: 4.90
# ================================================================================
# quesel produced confinets of one four zero nine one three strong forms of the mo
#  were slarbined in liects soktums stor city described have aviline in in can par
# jound caleed from groups di matogo sen milidance to workard often in main four n
# leme of eight lowallilanistrics record to ussures out theori but the reaxensamin
# g maka eam playud cuthed of location it quy rgnhaas liffelles between zove in cr
# ================================================================================
# Validation set perplexity: 4.50

# %% [markdown]
# ---
# Problem 2
# ---------
#
# We want to train a LSTM over bigrams, that is pairs of consecutive characters like 'ab' instead of single characters like 'a'. Since the number of possible bigrams is large, feeding them directly to the LSTM using 1-hot encodings will lead to a very sparse representation that is very wasteful computationally.
#
# a- Introduce an embedding lookup on the inputs, and feed the embeddings to the LSTM cell instead of the inputs themselves.
#
# b- Write a bigram-based LSTM, modeled on the character LSTM above.
#
# c- Introduce Dropout. For best practices on how to use Dropout in LSTMs, refer to this [article](http://arxiv.org/abs/1409.2329).
#
# ---

# %%
num_nodes = 64

graph = tf.Graph()
with graph.as_default():
  
  # Parameters:
  ## Input gate: input, previous output, and bias.
  #ix = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  #im = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  #ib = tf.Variable(tf.zeros([1, num_nodes]))
  ## Forget gate: input, previous output, and bias.
  #fx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  #fm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  #fb = tf.Variable(tf.zeros([1, num_nodes]))
  ## Memory cell: input, state and bias.                             
  #cx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  #cm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  #cb = tf.Variable(tf.zeros([1, num_nodes]))
  ## Output gate: input, previous output, and bias.
  #ox = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  #om = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  #ob = tf.Variable(tf.zeros([1, num_nodes]))
    
  ifcox = tf.Variable(tf.truncated_normal([vocabulary_size, 4*num_nodes], -0.1, 0.1))
  ifcom = tf.Variable(tf.truncated_normal([num_nodes, 4*num_nodes], -0.1, 0.1))
  ifcob = tf.Variable(tf.zeros([1, 4*num_nodes]))
  # Variables saving state across unrollings.
  saved_output = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  saved_state = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  # Classifier weights and biases.
  w = tf.Variable(tf.truncated_normal([num_nodes, vocabulary_size], -0.1, 0.1))
  b = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Definition of the cell computation.
  def lstm_cell(i1, i2, o, state):
    """Create a LSTM cell. See e.g.: http://arxiv.org/pdf/1402.1128v1.pdf
    Note that in this formulation, we omit the various connections between the
    previous state and the gates."""
    #input_gate = tf.sigmoid(tf.matmul(i, ix) + tf.matmul(o, im) + ib)
    #forget_gate = tf.sigmoid(tf.matmul(i, fx) + tf.matmul(o, fm) + fb)
    #update = tf.matmul(i, cx) + tf.matmul(o, cm) + cb
    #state = forget_gate * state + input_gate * tf.tanh(update)
    #output_gate = tf.sigmoid(tf.matmul(i, ox) + tf.matmul(o, om) + ob)
    
    embed1 = tf.nn.embedding_lookup(ifcox, i1)
    embed2 = tf.nn.embedding_lookup(ifcox, i2)
    embed = embed1 + embed2
    
    all_gates_state = embed + tf.matmul(o, ifcom) + ifcob
    input_gate = tf.sigmoid(all_gates_state[:, 0:num_nodes])
    forget_gate = tf.sigmoid(all_gates_state[:, num_nodes: 2*num_nodes])
    update = all_gates_state[:, 2*num_nodes: 3*num_nodes]
    state = forget_gate * state + input_gate * tf.tanh(update)
    output_gate = tf.sigmoid(all_gates_state[:, 3*num_nodes:])
    return output_gate * tf.tanh(state), state

  # Input data.
  train_data = list()
  for _ in range(num_unrollings + 1):
    train_data.append(
      tf.placeholder(tf.int64, shape=[batch_size,vocabulary_size])) ### <--------- look here
  train_inputs = train_data[:num_unrollings]
  train_labels = train_data[1:]  # labels are inputs shifted by one time step.

  # Unrolled LSTM loop.
  outputs = list()
  output = saved_output
  state = saved_state
  i1 = tf.constant(0, dtype=tf.int64)     # initial char is blank
  for i in train_inputs:
    i2 = i
    output, state = lstm_cell(i1, i2, output, state)
    outputs.append(output)
    i1 = i2

  # State saving across unrollings.
  with tf.control_dependencies([saved_output.assign(output),
                                saved_state.assign(state)]):
    # Classifier.
    logits = tf.nn.xw_plus_b(tf.concat(0, outputs), w, b)
    loss = tf.reduce_mean(
      tf.nn.softmax_cross_entropy_with_logits(
        logits, tf.concat(0, train_labels)))

  # Optimizer.
  global_step = tf.Variable(0)
  learning_rate = tf.train.exponential_decay(
    10.0, global_step, 5000, 0.1, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate)
  gradients, v = zip(*optimizer.compute_gradients(loss))
  gradients, _ = tf.clip_by_global_norm(gradients, 1.25)
  optimizer = optimizer.apply_gradients(
    zip(gradients, v), global_step=global_step)

  # Predictions.
  train_prediction = tf.nn.softmax(logits)
  
  # Sampling and validation eval: batch 1, no unrolling.
  sample_input = tf.placeholder(tf.float32, shape=[1, vocabulary_size])
  saved_sample_output = tf.Variable(tf.zeros([1, num_nodes]))
  saved_sample_state = tf.Variable(tf.zeros([1, num_nodes]))
  reset_sample_state = tf.group(
    saved_sample_output.assign(tf.zeros([1, num_nodes])),
    saved_sample_state.assign(tf.zeros([1, num_nodes])))
  sample_output, sample_state = lstm_cell(
    sample_input, saved_sample_output, saved_sample_state)
  with tf.control_dependencies([saved_sample_output.assign(sample_output),
                                saved_sample_state.assign(sample_state)]):
    sample_prediction = tf.nn.softmax(tf.nn.xw_plus_b(sample_output, w, b))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-caa33e6407bd> in <module>()
#      81     loss = tf.reduce_mean(
#      82       tf.nn.softmax_cross_entropy_with_logits(
# ---> 83         logits, tf.concat(0, train_labels)))
#      84
#      85   # Optimizer.
#
# /home/seag/Builds/Tensorflow/lib/python2.7/site-packages/tensorflow/python/ops/nn_ops.pyc in softmax_cross_entropy_with_logits(logits, labels, name)
#     221   # _CrossEntropyGrad() in nn_grad but not here.
#     222   cost, unused_backprop = gen_nn_ops._softmax_cross_entropy_with_logits(
# --> 223       logits, labels, name=name)
#     224   return cost
#     225
#
# /home/seag/Builds/Tensorflow/lib/python2.7/site-packages/tensorflow/python/ops/gen_nn_ops.pyc in _softmax_cross_entropy_with_logits(features, labels, name)
#     871   """
#     872   return _op_def_lib.apply_op("SoftmaxCrossEntropyWithLogits",
# --> 873                               features=features, labels=labels, name=name)
#     874
#     875
#
# /home/seag/Builds/Tensorflow/lib/python2.7/site-packages/tensorflow/python/ops/op_def_library.pyc in apply_op(self, op_type_name, name, **keywords)
#     423                   "%s type %s of argument '%s'." %
#     424                   (prefix, dtypes.as_dtype(attrs[input_arg.type_attr]).name,
# --> 425                    inferred_from[input_arg.type_attr]))
#     426
#     427           types = [values.dtype]
#
# TypeError: Input 'labels' of 'SoftmaxCrossEntropyWithLogits' Op has type int64 that does not match type float32 of argument 'features'.

# %%
num_steps = 7001
summary_frequency = 100

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  mean_loss = 0
  for step in range(num_steps):
    batches = train_batches.next()
    feed_dict = dict()
    for i in range(num_unrollings + 1):
      feed_dict[train_data[i]] = batches[i]
    _, l, predictions, lr = session.run(
      [optimizer, loss, train_prediction, learning_rate], feed_dict=feed_dict)
    mean_loss += l
    if step % summary_frequency == 0:
      if step > 0:
        mean_loss = mean_loss / summary_frequency
      # The mean loss is an estimate of the loss over the last few batches.
      print(
        'Average loss at step %d: %f learning rate: %f' % (step, mean_loss, lr))
      mean_loss = 0
      labels = np.concatenate(list(batches)[1:])
      print('Minibatch perplexity: %.2f' % float(
        np.exp(logprob(predictions, labels))))
      if step % (summary_frequency * 10) == 0:
        # Generate some samples.
        print('=' * 80)
        for _ in range(5):
          feed = sample(random_distribution())
          sentence = characters(feed)[0]
          reset_sample_state.run()
          for _ in range(79):
            prediction = sample_prediction.eval({sample_input: feed})
            feed = sample(prediction)
            sentence += characters(feed)[0]
          print(sentence)
        print('=' * 80)
      # Measure validation set perplexity.
      reset_sample_state.run()
      valid_logprob = 0
      for _ in range(valid_size):
        b = valid_batches.next()
        predictions = sample_prediction.eval({sample_input: b[0]})
        valid_logprob = valid_logprob + logprob(predictions, b[1])
      print('Validation set perplexity: %.2f' % float(np.exp(
        valid_logprob / valid_size)))
# Out:
# Initialized
# Average loss at step 0: 3.293377 learning rate: 10.000000
# Minibatch perplexity: 26.93
# ================================================================================
# po ym lzutuihi bxex ucvvqt  hl sdnydtf mc hbfou eekettsonnsmoswkdeoam   vu oqkht
# dlc vu wjiheygd s bnyf rbtnh atkdltsuajj wftahgz rlid nl sdlranfmw vl d yo otr o
# dss aieomptuuemacn edizac wnr osrlcvejjiguenhw en toeaxsakr btapnsjp syi rhmsxg
# dkndqi cg zg lvisfexj nvmsegjqrthelok trszaz sgo u koo wrnmss  nmie th wvgmn nei
# el p y  aez lalfmbreyqjycn mmapvaeickrrvdngbhtfieagzrrmkslh  tz rrbep rhf toty b
# ================================================================================
# Validation set perplexity: 19.90
# Average loss at step 100: 2.593230 learning rate: 10.000000
# Minibatch perplexity: 11.21
# Validation set perplexity: 12.16
# Average loss at step 200: 2.248885 learning rate: 10.000000
# Minibatch perplexity: 8.31
# Validation set perplexity: 8.71
# Average loss at step 300: 2.080215 learning rate: 10.000000
# Minibatch perplexity: 6.29
# Validation set perplexity: 7.97
# Average loss at step 400: 2.028352 learning rate: 10.000000
# Minibatch perplexity: 7.88
# Validation set perplexity: 7.81
# Average loss at step 500: 1.973563 learning rate: 10.000000
# Minibatch perplexity: 6.38
# Validation set perplexity: 6.95
# Average loss at step 600: 1.890506 learning rate: 10.000000
# Minibatch perplexity: 6.36
# Validation set perplexity: 6.93
# Average loss at step 700: 1.866158 learning rate: 10.000000
# Minibatch perplexity: 6.90
# Validation set perplexity: 6.52
# Average loss at step 800: 1.860760 learning rate: 10.000000
# Minibatch perplexity: 6.91
# Validation set perplexity: 6.46
# Average loss at step 900: 1.838184 learning rate: 10.000000
# Minibatch perplexity: 6.03
# Validation set perplexity: 6.27
# Average loss at step 1000: 1.839303 learning rate: 10.000000
# Minibatch perplexity: 6.45
# ================================================================================
# an west s anmif iste ial duspaciut dison is in consisial d e gined woir usor the
# quidic furtrant its a nover one five four of the macreter with dtsd capeosing mo
# fer c lid s hemzeria anchara ople s me tavin used tern fwormaters sermertim tamp
# w two exven as pruc anthough twan strapes is alpion of the continium reneticy on
# net but incessarial throue in phy oclinet gus duthes isiqies in the brox was the
# ================================================================================
# Validation set perplexity: 6.02
# Average loss at step 1100: 1.796841 learning rate: 10.000000
# Minibatch perplexity: 5.30
# Validation set perplexity: 6.08
# Average loss at step 1200: 1.765174 learning rate: 10.000000
# Minibatch perplexity: 6.40
# Validation set perplexity: 5.90
# Average loss at step 1300: 1.758232 learning rate: 10.000000
# Minibatch perplexity: 5.84
# Validation set perplexity: 5.86
# Average loss at step 1400: 1.762149 learning rate: 10.000000
# Minibatch perplexity: 6.34
# Validation set perplexity: 5.75
# Average loss at step 1500: 1.748639 learning rate: 10.000000
# Minibatch perplexity: 5.73
# Validation set perplexity: 5.52
# Average loss at step 1600: 1.732056 learning rate: 10.000000
# Minibatch perplexity: 5.50
# Validation set perplexity: 5.68
# Average loss at step 1700: 1.714636 learning rate: 10.000000
# Minibatch perplexity: 5.16
# Validation set perplexity: 5.42
# Average loss at step 1800: 1.690931 learning rate: 10.000000
# Minibatch perplexity: 5.08
# Validation set perplexity: 5.26
# Average loss at step 1900: 1.694639 learning rate: 10.000000
# Minibatch perplexity: 5.03
# Validation set perplexity: 5.41
# Average loss at step 2000: 1.675979 learning rate: 10.000000
# Minibatch perplexity: 4.90
# ================================================================================
# dhs from antwsenter vilt usubliss tester pession of the p by spear timate certy
# zend then most to the can dembeding nestuage link file suepicitial mos ng offere
# gis lightates tubly was airssifuctract in an hadeard present whell exvants velog
# obhs west br boli fire and wide loss secies for than coustinution for arsumise b
# al glough rueding callast that on genent frant to hecks prodected ius tamence pa
# ================================================================================
# Validation set perplexity: 5.26
# Average loss at step 2100: 1.684361 learning rate: 10.000000
# Minibatch perplexity: 4.96
# Validation set perplexity: 5.31
# Average loss at step 2200: 1.704361 learning rate: 10.000000
# Minibatch perplexity: 4.94
# Validation set perplexity: 5.13
# Average loss at step 2300: 1.702645 learning rate: 10.000000
# Minibatch perplexity: 6.32
# Validation set perplexity: 5.14
# Average loss at step 2400: 1.681998 learning rate: 10.000000
# Minibatch perplexity: 5.77
# Validation set perplexity: 5.27
# Average loss at step 2500: 1.685485 learning rate: 10.000000
# Minibatch perplexity: 5.88
# Validation set perplexity: 5.16
# Average loss at step 2600: 1.666275 learning rate: 10.000000
# Minibatch perplexity: 5.40
# Validation set perplexity: 5.01
# Average loss at step 2700: 1.681133 learning rate: 10.000000
# Minibatch perplexity: 5.34
# Validation set perplexity: 5.14
# Average loss at step 2800: 1.680231 learning rate: 10.000000
# Minibatch perplexity: 5.29
# Validation set perplexity: 5.24
# Average loss at step 2900: 1.671997 learning rate: 10.000000
# Minibatch perplexity: 6.24
# Validation set perplexity: 5.14
# Average loss at step 3000: 1.676860 learning rate: 10.000000
# Minibatch perplexity: 4.83
# ================================================================================
# y businest frogr of beofficaplitize pranutionon farrard don other pueling to reg
# n zero akeria k two one eers the s enuaking in two made time earth use eleasiol
# s the majo comma replocial to tws tch usion metotac field mevoutives of the russ
# line crestrettifur of deserpted is numinaning eflited alse the exchurt of itm ze
# tifing that amino is the frenchija seaced preadio on a alvembers piesable tasm w
# ================================================================================
# Validation set perplexity: 5.07
# Average loss at step 3100: 1.650584 learning rate: 10.000000
# Minibatch perplexity: 5.25
# Validation set perplexity: 5.03
# Average loss at step 3200: 1.633713 learning rate: 10.000000
# Minibatch perplexity: 5.47
# Validation set perplexity: 4.96
# Average loss at step 3300: 1.641699 learning rate: 10.000000
# Minibatch perplexity: 5.24
# Validation set perplexity: 4.87
# Average loss at step 3400: 1.629631 learning rate: 10.000000
# Minibatch perplexity: 5.26
# Validation set perplexity: 4.92
# Average loss at step 3500: 1.672846 learning rate: 10.000000
# Minibatch perplexity: 6.07
# Validation set perplexity: 4.91
# Average loss at step 3600: 1.649479 learning rate: 10.000000
# Minibatch perplexity: 5.26
# Validation set perplexity: 4.89
# Average loss at step 3700: 1.647433 learning rate: 10.000000
# Minibatch perplexity: 5.19
# Validation set perplexity: 4.90
# Average loss at step 3800: 1.652621 learning rate: 10.000000
# Minibatch perplexity: 6.17
# Validation set perplexity: 4.87
# Average loss at step 3900: 1.644662 learning rate: 10.000000
# Minibatch perplexity: 4.19
# Validation set perplexity: 4.85
# Average loss at step 4000: 1.636761 learning rate: 10.000000
# Minibatch perplexity: 5.32
# ================================================================================
# wern range of one nine tenenssartted sectry the indarams organis threatwouther a
#  c holdymea from hay off they mulantal mostfyii and anius deltgnkan fast irea la
# y mones the mirronal miljemant butchaden the officially was the umlater for anor
# ting the laser natues bexiname states britishus those for form curreether amomve
# kson the lipermation cidons to the willian calse as make and hars khen not sort
# ================================================================================
# Validation set perplexity: 4.71
# Average loss at step 4100: 1.619622 learning rate: 10.000000
# Minibatch perplexity: 4.69
# Validation set perplexity: 4.63
# Average loss at step 4200: 1.615867 learning rate: 10.000000
# Minibatch perplexity: 5.01
# Validation set perplexity: 4.65
# Average loss at step 4300: 1.620537 learning rate: 10.000000
# Minibatch perplexity: 5.56
# Validation set perplexity: 4.84
# Average loss at step 4400: 1.609189 learning rate: 10.000000
# Minibatch perplexity: 5.47
# Validation set perplexity: 4.68
# Average loss at step 4500: 1.636669 learning rate: 10.000000
# Minibatch perplexity: 5.02
# Validation set perplexity: 4.77
# Average loss at step 4600: 1.618736 learning rate: 10.000000
# Minibatch perplexity: 5.32
# Validation set perplexity: 4.71
# Average loss at step 4700: 1.615074 learning rate: 10.000000
# Minibatch perplexity: 4.87
# Validation set perplexity: 4.74
# Average loss at step 4800: 1.608948 learning rate: 10.000000
# Minibatch perplexity: 4.72
# Validation set perplexity: 4.74
# Average loss at step 4900: 1.617202 learning rate: 10.000000
# Minibatch perplexity: 5.19
# Validation set perplexity: 4.71
# Average loss at step 5000: 1.612680 learning rate: 1.000000
# Minibatch perplexity: 4.85
# ================================================================================
# x parvision of that by constrainwatined perstrungaon conlip smallend the world i
# ckish remating five mistic rukers to were moned the dirgua have that special con
# dated is ited gold vier wince the wan a shew dia of europe architecturing are be
# ent of the followard novy that the componed that be yoush one three seven tox ca
# ful labriin mills which theory inv besumemblefic that sharks world botk came coi
# ================================================================================
# Validation set perplexity: 4.69
# Average loss at step 5100: 1.592694 learning rate: 1.000000
# Minibatch perplexity: 5.17
# Validation set perplexity: 4.62
# Average loss at step 5200: 1.587429 learning rate: 1.000000
# Minibatch perplexity: 5.17
# Validation set perplexity: 4.60
# Average loss at step 5300: 1.594895 learning rate: 1.000000
# Minibatch perplexity: 5.18
# Validation set perplexity: 4.60
# Average loss at step 5400: 1.590079 learning rate: 1.000000
# Minibatch perplexity: 4.64
# Validation set perplexity: 4.55
# Average loss at step 5500: 1.581882 learning rate: 1.000000
# Minibatch perplexity: 5.38
# Validation set perplexity: 4.53
# Average loss at step 5600: 1.564071 learning rate: 1.000000
# Minibatch perplexity: 4.39
# Validation set perplexity: 4.48
# Average loss at step 5700: 1.576479 learning rate: 1.000000
# Minibatch perplexity: 4.72
# Validation set perplexity: 4.45
# Average loss at step 5800: 1.601382 learning rate: 1.000000
# Minibatch perplexity: 4.66
# Validation set perplexity: 4.48
# Average loss at step 5900: 1.581591 learning rate: 1.000000
# Minibatch perplexity: 5.29
# Validation set perplexity: 4.49
# Average loss at step 6000: 1.581957 learning rate: 1.000000
# Minibatch perplexity: 4.68
# ================================================================================
# ons the fina remains invext chilcsimal uised elemiting a cove face wem by the ea
#  the openst by progrims braphic general one zero s while sparge daing than two s
# ger alyant starting bodhaf was music is simpless of french one seven one through
# s impositions laxisher phocroronic meador on this otherong are study responsic t
# query couds formed and the since one five six nimtonent by novers s ves ottessio
# ================================================================================
# Validation set perplexity: 4.46
# Average loss at step 6100: 1.571145 learning rate: 1.000000
# Minibatch perplexity: 4.33
# Validation set perplexity: 4.49
# Average loss at step 6200: 1.584520 learning rate: 1.000000
# Minibatch perplexity: 4.70
# Validation set perplexity: 4.51
# Average loss at step 6300: 1.584016 learning rate: 1.000000
# Minibatch perplexity: 5.23
# Validation set perplexity: 4.53
# Average loss at step 6400: 1.568721 learning rate: 1.000000
# Minibatch perplexity: 4.18
# Validation set perplexity: 4.53
# Average loss at step 6500: 1.556218 learning rate: 1.000000
# Minibatch perplexity: 5.40
# Validation set perplexity: 4.55
# Average loss at step 6600: 1.597963 learning rate: 1.000000
# Minibatch perplexity: 5.58
# Validation set perplexity: 4.51
# Average loss at step 6700: 1.569481 learning rate: 1.000000
# Minibatch perplexity: 5.42
# Validation set perplexity: 4.53
# Average loss at step 6800: 1.574011 learning rate: 1.000000
# Minibatch perplexity: 4.82
# Validation set perplexity: 4.57
# Average loss at step 6900: 1.568783 learning rate: 1.000000
# Minibatch perplexity: 4.86
# Validation set perplexity: 4.54
# Average loss at step 7000: 1.585995 learning rate: 1.000000
# Minibatch perplexity: 4.90
# ================================================================================
# quesel produced confinets of one four zero nine one three strong forms of the mo
#  were slarbined in liects soktums stor city described have aviline in in can par
# jound caleed from groups di matogo sen milidance to workard often in main four n
# leme of eight lowallilanistrics record to ussures out theori but the reaxensamin
# g maka eam playud cuthed of location it quy rgnhaas liffelles between zove in cr
# ================================================================================
# Validation set perplexity: 4.50

# %% [markdown]
# ---
# Problem 3
# ---------
#
# (difficult!)
#
# Write a sequence-to-sequence LSTM which mirrors all the words in a sentence. For example, if your input is:
#
#     the quick brown fox
#
# the model should attempt to output:
#
#     eht kciuq nworb xof
#
# Refer to the lecture on how to put together a sequence-to-sequence model, as well as [this article](http://arxiv.org/abs/1409.3215) for best practices.
#
# ---
